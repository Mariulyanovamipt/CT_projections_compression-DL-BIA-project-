# %% [markdown]
# First glance at data and pydicom library

# %%
#!pip install matplotlib

# %%
import numpy as np
from matplotlib import pyplot as plt

#you need to chande kernel to environment, which has numpy>=1.20 and pydicom=2.3.0.dev0

# %%
#%pip uninstall numpy
#%pip install numpy==1.20
#%pip install pydicom --user

# %%
from pydicom import dcmread
from pydicom.data import get_testdata_file

# %%
filename = 'test_data/Full_dose/1-00001.dcm'
ds = dcmread(filename)
print(ds.PixelData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20500\3987150998.py in <module>
#       1 filename = 'test_data/Full_dose/1-00001.dcm'
# ----> 2 ds = dcmread(filename)
#       3 print(ds.PixelData)
#
# ~\anaconda3\envs\pydicom_odl\lib\site-packages\pydicom\filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     999         caller_owns_file = False
#    1000         logger.debug("Reading file '{0}'".format(fp))
# -> 1001         fp = open(fp, 'rb')
#    1002     elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#    1003         raise TypeError("dcmread: Expected a file path or a file-like, "
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_data/Full_dose/1-00001.dcm'

# %%
print(ds) #info about projection
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 188
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Raw Data Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113713.4.2.421442158711944606717649601682127798710
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Raw Data Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113713.4.2.421442158711944606717649601682127798710
# (0008, 0020) Study Date                          DA: '20180830'
# ...

# %%
import pydicom
print(pydicom.__version__)
import numpy
print(numpy.__version__)
# Out:
# 2.2.2
# 1.21.5

# %%
print(ds.pixel_array)
print(ds.pixel_array.shape)
# Out:
# [[2161 2514 2851 ... 3103 3103 3103]
#  [2677 2850 3048 ... 3396 3396 3396]
#  [3011 3168 3355 ... 3546 3546 3546]
#  ...
#  [1027 1045 1084 ... 1055 1055 1055]
#  [1047  975 1017 ... 1018 1018 1018]
#  [1103 1155 1151 ... 1152 1152 1152]]
# (736, 64)

# %% [markdown]
# #Reconstruction

# %%
#data_dir='manifest-1643214718297/LDCT-and-Projection-data/C002/12-23-2021-NA-NA-62464/1.000000-Full dose projections-22038'
data_dir='test_data/C002/08_30_2018/full_dose'
data_dir2='test_data/C002/12_23_2021/full_dose'

# %%
example = data_dir+'/'+'1-00001.dcm'
dcm_1 = dcmread(example)
print(dcm_1.PixelData)
# Out:
# b'q\x08\xd2\t#\x0b\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c&\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0c\x1f\x0cu\n"\x0b\xe8\x0bD\rD\rD\rD\rD\rD\rD\rD\rD\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rN\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\rD\r\xc3\x0b`\x0c\x1b\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xdf\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda\r\xda
# ...

# %%
im = data_dir2+'/'+'1-223.dcm'
im_1 = dcmread(im)
#print(im_1.PixelData)
print(im_1.pixel_array)
print(im_1.pixel_array.shape)

print(type(im_1.pixel_array))
# Out:
# [[24 24 24 ... 24 24 24]
#  [24 24 24 ... 24 24 24]
#  [24 24 24 ... 24 24 24]
#  ...
#  [24 24 24 ... 24 24 24]
#  [24 24 24 ... 24 24 24]
#  [24 24 24 ... 24 24 24]]
# (512, 512)
# <class 'numpy.ndarray'>

# %%
import os
import re
file_list=os.listdir(data_dir2)
#files = [f for f in os.listdir('.') if re.match('*.dcm', f)]
import glob
files = glob.glob(data_dir2+'/'+'*.dcm')
print(files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
#       1 import os
#       2 import re
# ----> 3 file_list=os.listdir(data_dir2)
#       4 #files = [f for f in os.listdir('.') if re.match('*.dcm', f)]
#       5 import glob
#
# NameError: name 'data_dir2' is not defined

# %%
#combining all imgs to list
all_imgs=[]
for f in file_list:
    dcm = data_dir2+'/'+f
    dcm_1 = dcmread(dcm)
    im_1=dcm_1.pixel_array
    all_imgs.append(im_1)
print(len(all_imgs))
# Out:
# 280

# %%
#list to tensor
img_3d=np.stack(all_imgs)
print(img_3d.shape)
# Out:
# (280, 512, 512)

# %%
plt.imshow(img_3d[:,:,220], cmap = 'gray')
plt.colorbar()

# %%
plt.imshow(img_3d[:,100, :], cmap='gray')

# %%
plt.imshow(img_3d[:,:,100],cmap='gray')

# %%
#let's write a function to extract 3d image from directory
def img_3d_from_dir(data_dir):
    file_list=os.listdir(data_dir)
    #print(file_list)
    all_imgs=[]
    for f in file_list:
        dcm = data_dir+'/'+f
        dcm_1 = dcmread(dcm)
        im_1=dcm_1.pixel_array
        all_imgs.append(im_1)
    img_3d=np.stack(all_imgs)
    return img_3d

# %%
data_dir='test_data/C002/08_30_2018/full_dose'
IM=img_3d_from_dir(data_dir)
print(IM.shape)
plt.imshow(IM[:,100, :], cmap='gray')
# Out:
# (11072, 736, 64)

# %%
print(IM.shape)
plt.imshow(IM[2500,:, :].T, cmap='gray')
plt.colorbar()
# Out:
# (11072, 736, 64)

# %%
print(IM.shape)
plt.imshow(IM[:,:, 35], cmap='gray')
# Out:
# (11072, 736, 64)

# %% [markdown]
# MAKING VIDEO (just for fun)

# %%
#%pip install moviepy
# Out:
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110743 sha256=97a859421685ba65af4a32cdbd7baf9a0d89fe0ba60a17d9ff10b17930158aa9
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\e4\a4\db\0368d3a04033da662e13926594b3a8cf1aa4ffeefe570cfac1
# ...
#   Created wheel for proglog: filename=proglog-0.1.9-py3-none-any.whl size=6157 sha256=00627c60d32c5da4b3a307a01280ce6efe12bcad3d6811232ce4258423e0228e
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\22\82\ff\56950e4b223a69eda3a2bdeaef2ae4b274c3d1ced9b5814c99
# Successfully built moviepy proglog
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\User\anaconda3\envs\pydicom_2\Scripts' which is not on PATH.
# ...

# %%
#import os
#import moviepy.video.io.ImageSequenceClip
#from PIL import Image
#import numpy as np
#data_dir2='test_data/C002/12_23_2021/full_dose'

#image_folder=data_dir2

#fps=1
#image_files =[Image.fromarray(im, 'L') for im in img_3d_from_dir(data_dir2)]
#print(image_files)
#clip = moviepy.video.io.ImageSequenceClip.ImageSequenceClip(image_files, fps=fps)
#clip.write_videofile('my_video.mp4')

# %%
#%pip install Pillow
#%pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data_dir2='test_data/C002/12_23_2021/full_dose'
IM3d=img_3d_from_dir(data_dir2)
im_1=IM3d[1]
print(im_1.shape)
img = Image.fromarray(im_1, 'L')
img.show()
# Out:
# (512, 512)

# %%
#writing a video pf projections
import numpy as np
import cv2
duration = 2
fps = 4
image_files =[im for im in img_3d_from_dir(data_dir2)]
size = image_files[0].shape
duration = len(image_files)/fps #num of frames / fps
out = cv2.VideoWriter('output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (size[1], size[0]), False)
for i in range(len(image_files)):
    data = image_files[i]
    out.write(data)
out.release()

# %% [markdown]
# ASTRA TOOLBOX

# %%
# %conda install -c astra-toolbox astra-toolbox
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3\envs\pydicom_odl
#
#   added / updated specs:
#     - astra-toolbox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     astra-toolbox-2.1.0        |   py37he1a4279_0         355 KB  astra-toolbox
#     ------------------------------------------------------------
#                                            Total:         355 KB
#
# The following NEW packages will be INSTALLED:
#
#   astra-toolbox      astra-toolbox/win-64::astra-toolbox-2.1.0-py37he1a4279_0
#   cudatoolkit        pkgs/main/win-64::cudatoolkit-11.3.1-h59b6b97_2
#   libastra           astra-toolbox/win-64::libastra-2.1.0-cuda_11.3_0
#
#
#
# ...
#
# astra-toolbox-2.1.0  | 355 KB    |            |   0%
# astra-toolbox-2.1.0  | 355 KB    | ########## | 100%
# ...

# %%
import astra
astra.test()
# Out:
# No GPU support available
# ASTRA Toolbox v2.1.0
# Testing basic CPU 2D functionality... Ok

# %%
#let's reveal info about images
im = data_dir+'/'+'1-02223.dcm'
im_1 = dcmread(im)
print(im_1)
print(im_1.Modality)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 188
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Raw Data Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113713.4.2.45455756212000114726742959580568446733
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Raw Data Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113713.4.2.45455756212000114726742959580568446733
# (0008, 0020) Study Date                          DA: '20180830'
# ...

# %%
#collecting essential info
distance_source_origin = 300  # [mm]
distance_origin_detector = 100  # [mm]
detector_pixel_size = 1.05  # [mm]
detector_rows = 512  # Vertical size of detector [pixels].
detector_cols = 512  # Horizontal size of detector [pixels].
num_of_projections = 280
angles = np.linspace(0, 2 * np.pi, num=num_of_projections, endpoint=False)

# %%
#projections = np.zeros((detector_rows, num_of_projections, detector_cols))
#for i in range(num_of_projections):
    #im = imread(join(input_dir, 'proj%04d.tif' % i)).astype(float)
    #im /= 65535
    #projections[:, i, :] = im

projections=np.swapaxes(img_3d_from_dir(data_dir2), 0, 1)
print(projections.shape)
# Out:
# (512, 280, 512)

# %%
proj_geom = astra.create_proj_geom('cone', 1, 1, detector_rows, detector_cols, angles,
                         (distance_source_origin + distance_origin_detector) /
                         detector_pixel_size, 0)
projections_id = astra.data3d.create('-sino', proj_geom, projections)

# %%
import tomosipo as ts
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 import tomosipo as ts
#
# ModuleNotFoundError: No module named 'tomosipo'

# %%
# !pip install git+https://github.com/ahendriksen/tomosipo
# Out:
# ...
#   Cloning https://github.com/ahendriksen/tomosipo to c:\users\user\appdata\local\temp\pip-req-build-o7tvaeeq
# ...
#   Running command git clone -q https://github.com/ahendriksen/tomosipo 'C:\Users\User\AppData\Local\Temp\pip-req-build-o7tvaeeq'

# %%
#%conda install -c tomosipo tomosipo
# %conda install -c odlgroup odl==0.7.0
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3\envs\pydicom_odl
#
#   added / updated specs:
#     - odl==0.7.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     future-0.18.2              |           py37_1         646 KB
#     kiwisolver-1.3.2           |   py37hd77b12b_0          56 KB
#     matplotlib-3.5.0           |   py37haa95532_0          28 KB
#     matplotlib-base-3.5.0      |   py37h6214cd6_0         5.6 MB
#     mkl-service-2.4.0          |   py37h2bbff1b_0          49 KB
#     mkl_fft-1.3.1              |   py37h277e83a_0         135 KB
#     mkl_random-1.2.2           |   py37hf11a4ad_0         216 KB
#     numpy-1.21.5               |   py37ha4e8547_0           9 KB
#     numpy-base-1.21.5          |   py37hc2deb75_0         4.3 MB
# ...

# %%
# !pip install odl==0.7.0
# Out:
# ...
#   Attempting uninstall: odl
#     Found existing installation: odl 0.7.0
#     Uninstalling odl-0.7.0:
#       Successfully uninstalled odl-0.7.0
# ...

# %%
import numpy as np
import odl

# %%
# !pip install https://github.com/odlgroup/odl/archive/master.zip
# Out:
# ...
#   Using cached https://github.com/odlgroup/odl/archive/master.zip
# ...
#   Created wheel for odl: filename=odl-1.0.0.dev0-py2.py3-none-any.whl size=762326 sha256=566ec71be06cab1aa513daffc817205165057c9fd4c7f9f8c6b805de44827115
#   Stored in directory: C:\Users\User\AppData\Local\Temp\pip-ephem-wheel-cache-rqktf1bi\wheels\66\fe\90\e446672a56fb85f00ce41db9e8c4682731fbb6e2a66dcde3ef
# Successfully built odl
# ...
#   Attempting uninstall: odl
#     Found existing installation: odl 0.5.2
#     Uninstalling odl-0.5.2:
#       Successfully uninstalled odl-0.5.2
# ...

# %%
# Reconstruction space: discretized functions on the cube
# [-20, 20]^2 x [0, 40] with 300 samples per dimension.
reco_space = odl.uniform_discr(
    min_pt=[-20, -20, 0], max_pt=[20, 20, 40], shape=[300, 300, 300],
    dtype='float32')

# Make a helical cone beam geometry with flat detector
# Angles: uniformly spaced, n = 2000, min = 0, max = 8 * 2 * pi
angle_partition = odl.uniform_partition(0, 8 * 2 * np.pi, 2000)
# Detector: uniformly sampled, n = (512, 64), min = (-50, -3), max = (50, 3)
detector_partition = odl.uniform_partition([-50, -3], [50, 3], [512, 64])
# Spiral has a pitch of 5, we run 8 rounds (due to max angle = 8 * 2 * pi)
geometry = odl.tomo.ConeBeamGeometry(angle_partition, detector_partition, src_radius=100, det_radius=100,
    pitch=5.0)

# Ray transform (= forward projection).
ray_trafo = odl.tomo.RayTransform(reco_space, geometry)

# Create a discrete Shepp-Logan phantom (modified version)
phantom = odl.phantom.shepp_logan(reco_space, modified=True)

# Create projection data by calling the ray transform on the phantom
proj_data = ray_trafo(phantom)

# Back-projection can be done by simply calling the adjoint operator on the
# projection data (or any element in the projection space).
backproj = ray_trafo.adjoint(proj_data)

# Shows a slice of the phantom, projections, and reconstruction
phantom.show(coords=[None, None, 20], title='Phantom, Middle Z Slice')
proj_data.show(coords=[2 * np.pi, None, None],
               title='Projection After Exactly One Turn')
proj_data.show(coords=[None, None, 0], title='Sinogram, Middle Slice')
backproj.show(coords=[None, None, 20], title='Back-projection, Middle Z Slice',
              force_show=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10100\105404101.py in <module>
#      11 detector_partition = odl.uniform_partition([-50, -3], [50, 3], [512, 64])
#      12 # Spiral has a pitch of 5, we run 8 rounds (due to max angle = 8 * 2 * pi)
# ---> 13 geometry = odl.tomo.ConeBeamGeometry(angle_partition, detector_partition, src_radius=100, det_radius=100,
#      14     pitch=5.0)
#      15
#
# AttributeError: module 'odl.tomo' has no attribute 'ConeBeamGeometry'

# %%
"""Example using FBP in helical 3D geometry using `fbp_op`.
Note that the FBP is only approximate in this geometry, but still gives a
decent reconstruction that can be used as an initial guess in more complex
methods.
In helical geometries, the data are in general over-sampled which causes
streak artefacts and a wrong scaling. This can be reduced using a
Tam-Danielson window.
"""

import numpy as np
import odl


# --- Set up geometry of the problem --- #


# Reconstruction space: discretized functions on the cube
# [-20, 20]^3  with 200 samples per dimension.
space = odl.uniform_discr(
    min_pt=[-20, -20, -20], max_pt=[20, 20, 20], shape=[200, 200, 200],
    dtype='float32')

# Create helical geometry
geometry = odl.tomo.helical_geometry(space,
                                     src_radius=100, det_radius=100,
                                     num_turns=7.5, num_angles=1000)

# --- Create Filtered Back-projection (FBP) operator --- #


# Ray transform (= forward projection).
ray_trafo = odl.tomo.RayTransform(space, geometry)

# Unwindowed fbp
# We select a Hamming filter, and only use the lowest 80% of frequencies to
# avoid high frequency noise.
fbp = odl.tomo.fbp_op(ray_trafo, filter_type='Hamming', frequency_scaling=0.8)

# Create Tam-Danielson window to improve result
windowed_fbp = fbp * odl.tomo.tam_danielson_window(ray_trafo)


# --- Show some examples --- #


# Create a discrete Shepp-Logan phantom (modified version)
phantom = odl.phantom.shepp_logan(space, modified=True)

# Create projection data by calling the ray transform on the phantom
proj_data = ray_trafo(phantom)

# Calculate FBP reconstructions, once without window, once with window
fbp_reconstruction = fbp(proj_data)
w_fbp_reconstruction = windowed_fbp(proj_data)

# Show a slice of phantom, projections, and reconstruction
phantom.show(title='Phantom',
             coords=[0, None, None], clim=[-0.1, 1.1])
proj_data.show(title='Simulated Data (Sinogram)')
fbp_reconstruction.show(title='Filtered Back-projection',
                        coords=[0, None, None], clim=[-0.1, 1.1])
w_fbp_reconstruction.show(title='Windowed Filtered back-projection',
                          coords=[0, None, None], clim=[-0.1, 1.1],
                          force_show=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10100\1860883196.py in <module>
#      30
#      31 # Ray transform (= forward projection).
# ---> 32 ray_trafo = odl.tomo.RayTransform(space, geometry)
#      33
#      34 # Unwindowed fbp
#
# ~\anaconda3\envs\pydicom_odl\lib\site-packages\odl\tomo\operators\ray_trafo.py in __init__(self, domain, geometry, **kwargs)
#     381         super(RayTransform, self).__init__(
#     382             reco_space=domain, proj_space=range, geometry=geometry,
# --> 383             variant='forward', **kwargs)
#     384
#     385     def _call_real(self, x_real, out_real):
#
# ~\anaconda3\envs\pydicom_odl\lib\site-packages\odl\tomo\operators\ray_trafo.py in __init__(self, reco_space, geometry, variant, **kwargs)
#     159             if geometry.ndim > 2 and impl.endswith('cpu'):
# ...

# %%
from odl.tomo import ConeBeamGeometry
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10100\3530868779.py in <module>
# ----> 1 from odl.tomo import ConeBeamGeometry
#
# ImportError: cannot import name 'ConeBeamGeometry' from 'odl.tomo' (C:\Users\User\anaconda3\envs\pydicom_odl\lib\site-packages\odl\tomo\__init__.py)

# %%
#dir(odl.tomo) this is for vesri
# Out:
# ['ASTRA_AVAILABLE',
#  'ASTRA_CUDA_AVAILABLE',
#  'ASTRA_VERSION',
#  'AstraCudaBackProjectorImpl',
#  'AstraCudaProjectorImpl',
#  'AxisOrientedGeometry',
#  'CircleSectionDetector',
#  'ConeFlatGeometry',
#  'Detector',
#  'DivergentBeamGeometry',
#  'FanFlatGeometry',
#  'Flat1dDetector',
#  'Flat2dDetector',
#  'Geometry',
#  'Parallel2dGeometry',
#  'Parallel3dAxisGeometry',
#  'Parallel3dEulerGeometry',
#  'ParallelBeamGeometry',
#  'ParallelHoleCollimatorGeometry',
#  'RayBackProjection',
#  'RayTransform',
#  'SKIMAGE_AVAILABLE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'analytic',
#  'astra_algorithm',
#  'astra_conebeam_2d_geom_to_vec',
#  'astra_conebeam_3d_geom_to_vec',
#  'astra_cpu_back_projector',
#  'astra_cpu_forward_projector',
#  'astra_data',
#  'astra_parallel_3d_geom_to_vec',
#  'astra_projection_geometry',
# ...

# %%
#dir(odl.tomo) #this is for vesrion 0.5.2
# Out:
# ['ASTRA_AVAILABLE',
#  'ASTRA_CUDA_AVAILABLE',
#  'AxisOrientedGeometry',
#  'CircleSectionDetector',
#  'CircularConeFlatGeometry',
#  'Detector',
#  'DivergentBeamGeometry',
#  'FanFlatGeometry',
#  'Flat1dDetector',
#  'Flat2dDetector',
#  'FlatDetector',
#  'Geometry',
#  'HelicalConeFlatGeometry',
#  'Parallel2dGeometry',
#  'Parallel3dAxisGeometry',
#  'Parallel3dEulerGeometry',
#  'ParallelGeometry',
#  'ParallelHoleCollimatorGeometry',
#  'RayBackProjection',
#  'RayTransform',
#  'SCIKIT_IMAGE_AVAILABLE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'astra_algorithm',
#  'astra_conebeam_2d_geom_to_vec',
#  'astra_conebeam_3d_geom_to_vec',
#  'astra_cpu_back_projector',
#  'astra_cpu_forward_projector',
#  'astra_cuda_back_projector',
#  'astra_cuda_forward_projector',
#  'astra_data',
#  'astra_parallel_3d_geom_to_vec',
# ...

# %%
dir(odl.tomo.geometry)
# Out:
# ['AxisOrientedGeometry',
#  'CircleSectionDetector',
#  'ConeFlatGeometry',
#  'Detector',
#  'DivergentBeamGeometry',
#  'FanFlatGeometry',
#  'Flat1dDetector',
#  'Flat2dDetector',
#  'Geometry',
#  'Parallel2dGeometry',
#  'Parallel3dAxisGeometry',
#  'Parallel3dEulerGeometry',
#  'ParallelBeamGeometry',
#  'ParallelHoleCollimatorGeometry',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'cone_beam_geometry',
#  'conebeam',
#  'detector',
#  'geometry',
#  'helical_geometry',
#  'parallel',
#  'parallel_beam_geometry',
#  'spect']

# %%
dir(odl.tomo.geometry.conebeam)
# Out:
# ['AxisOrientedGeometry',
#  'ConeFlatGeometry',
#  'DivergentBeamGeometry',
#  'FanFlatGeometry',
#  'Flat1dDetector',
#  'Flat2dDetector',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'absolute_import',
#  'array_str',
#  'cone_beam_geometry',
#  'division',
#  'euler_matrix',
#  'helical_geometry',
#  'indent',
#  'is_inside_bounds',
#  'np',
#  'print_function',
#  'signature_string',
#  'transform_system',
#  'uniform_partition']

# %%
print(odl.__version__)
# Out:
# 0.7.0

# %%
# !python --version
# Out:
# Python 3.8.8

# %% [raw]
# MEAN and STD OF ALL IMGS

# %%
#data_dir='manifest-1643214718297/LDCT-and-Projection-data/C002/12-23-2021-NA-NA-62464/1.000000-Full dose projections-22038'
data_dir='test_data/C002/08_30_2018/full_dose'
data_dir2='test_data/C002/12_23_2021/full_dose'

# %%
data_MY='C:/Users/User/Desktop/philips/vqvae2/dataset_MY/train_init'

# %%
import os
def img_3d_from_dir(data_dir):
    file_list=os.listdir(data_dir)
    #print(file_list)
    all_imgs=[]
    for f in file_list:
        dcm = data_dir+'/'+f
        dcm_1 = dcmread(dcm)
        im_1=dcm_1.pixel_array
        all_imgs.append(im_1)
    img_3d=np.stack(all_imgs)
    return img_3d

# %%
IMG=img_3d_from_dir(data_MY)
print(len(IMG))
# Out:
# 11062

# %%
MEAN = np.mean(IMG)

# %%
print(MEAN)
# Out:
# 15397.89470489686

# %%
STD = np.std(IMG)

# %%
print(STD)
# Out:
# 11227.287447554765

# %%
MAX = np.max(IMG)
MIN = np.min(IMG)
print(MAX)
print(MIN)
# Out:
# 65535
# 0

# %%
f=dcmread(data_MY+'/1-00001.dcm').pixel_array
print(np.mean(f))
print(np.max(f))
print(np.min(f))
# Out:
# 15666.00827955163
# 27331
# 958
